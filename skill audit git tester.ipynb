# %%
## git tester sheet for skill audit screen shots


##task two

# %%
import matplotlib.pyplot as plt
import numpy as np

##

x = np.arange(-2*np.pi, 2*np.pi, 0.01)

e= 2* x + np.sin(np.pi/3)

y= np.exp(-x)

plt.plot(x,y)
plt.show()

# %%
import numpy as np

a = 2 

n = int(input("number"))

while n != 0:
    a = (5*a)+2
    n = (n- 1)
    print(a)
    
    if n <=0:
        print(a)
        break
# Out:
# 12
# 62
# 312
# 1562
# 7812
# 39062
# 195312
# 976562
# 976562

# %%
##task 2 (iii)/(iv)

from random import seed

from random import randint

seed(15)

for _ in range (1):
    value = randint (100,999)
    print (value)

    x = 100

while x <= value:
    x = x + 10
    print (x)
    if x > value:
        break

while x >= value:
    x = x -1
    print (x)
    if x == value:
        break
# Out:
# 313
# 110
# 120
# 130
# 140
# 150
# 160
# 170
# 180
# 190
# 200
# 210
# 220
# 230
# 240
# 250
# 260
# 270
# 280
# 290
# 300
# 310
# 320
# 319
# 318
# 317
# 316
# 315
# 314
# 313
